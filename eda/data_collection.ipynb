# %% [markdown]
# ## workflow
# #### background and tools
# `python libraries, jupyter notebooks`
#
# `basic statistics including probability, calculating moments, Bayes' Rule`
#
# - problem statement : what problem are you trying to solve?
# - data collection : what data do you need to solve it?
# - Data Exploration & Preprocessing : how should you clean your data so your model can use it?
# - Modeling : Build a model to solve your problem?
# - Validation : Did I solve the problem?
# - Decision Making & Deployment : Communicate with stakeholders and push into production.

# %%
# %pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 748 kB 4.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 313 kB 42.2 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import pandas as pd
import sqlite3 as sq3
from pymongo import MongoClient

# %%
# retrieving data from CSV and JSON files
filepath = '../crypto_urls.csv'

# read the CSV file 
data = pd.read_csv(filepath)

# different delimiters - tab, semicolon, pipe,

# for tab-separated file (.tsv)
# data = pd.read_csv(filepath, sep='\t')

# for space-separated file
# data = pd.read_csv(filepath, delim_whitespace=True)

# don't use first row as header
# data = pd.read_csv(filepath, header=None)

# to specify the column names
# data = pd.read_csv(filepath, names=['col1', 'col2', 'col3'])

# custom missing values
# data = pd.read_csv(filepath, na_values=['NA', 'N/A', 'NULL'])

# print the first 5 rows of the dataframe
print(data.iloc[:5])
# Out:
#                              url
# 0         https://unixgaming.org
# 1  https://app.bakedpotatoes.dog
# 2    https://realtrumpmania.com/
# 3            https://behodler.io
# 4          https://merchdao.com/

# %%
filepath = '../crypto_url_data.json'

# read the JSON file
data = pd.read_json(filepath)

# write the dataframe to a JSON file
# data.to_json('output.json', orient='records', lines=True)

# print the first 5 rows of the dataframe
print(data.iloc[:5])
# Out:
#                                        url  label  label_no
# 0            https://arkham-airdrop.online   scam         1
# 1  https://swiftcoinwalletparcel.pages.dev   scam         1
# 2         https://traitsniper-airdrop.info   scam         1
# 3                       https://smardex.io  legit         0
# 4                https://notcoinwallet.xyz   scam         1

# %%
# Download the database
# !wget -P data https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0232EN-SkillsNetwork/asset/baseball.db

# !wget -P data https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0232EN-SkillsNetwork/asset/classic_rock.db

# %%
# retrieving data from a SQL Database
path = 'data/classic_rock.db'

# connect to the SQLite database
conn = sq3.connect(path)

# write a SQL query to retrieve data
query = """
SELECT *
    FROM rock_songs
    ;
"""

# query = """
# SELECT *
#     FROM allstarfull
#     ;
# """

# execute the query and store the result in a dataframe
data = pd.read_sql(query, conn)

# print the first 5 rows of the dataframe
print(data.iloc[:5])

# %%
# retrieving data from a NoSQL Database

# connect to the MongoDB server
conn = MongoClient()

# list all databases
dbs = conn.list_database_names()

# specify the database and collection
db = conn.database_name

# create a cursor object using a query
cursor = db.collection_name.find({})

# expand cursor and construct a dataframe
data = pd.DataFrame(list(cursor))
