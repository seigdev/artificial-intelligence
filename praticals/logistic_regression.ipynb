# %%
import os
print("Current Working Directory:", os.getcwd())
#
# Out:
# Current Working Directory: /Users/sooreoluwa/Projects/ai/praticals

# %%
import json

file_path = "../resources/tweets.json"

# Load JSON data from a file
with open(file_path, 'r') as file:
    tweets = json.load(file)

# Extract the 'text' field from each tweet
tweet_texts = [tweet['tweet']['full_text'] for tweet in tweets]

print(tweet_texts)
# Out:
# ['@Yadubai_manji Come be like say dem won win league', '@DaizGone @fredtosan Firing power', 'Forest no come play https://t.co/SPGCzuPoMS', 'See downgrade https://t.co/FwEOJPo1R4', '🤣🤣🤣 https://t.co/RM2jA1a0B7', 'Wolves all the way https://t.co/k2zlH1nCsI', 'Haaland go still win this golden boot sha', 'pep nor be dem divorce you na 😩😭😂😂', 'Highest way Man U fit finish this season na 10th', 'RT @EplPidgin: Man U just dey confuse person \n\nUna good abi una no good?', 'Man u 1 : 4 Brighton \n\nDey road dey come', '3 consecutive seasons. United never win Brighton', 'Man U just dey confuse person \n\nUna good abi una no good?', '@Narcissist___01 Maybe sha', '@bencasky This one no sure, games still plenty', 'Just see Tottenham abeg https://t.co/3MgULqGY1L', 'Nottingham Forest go finish top 5 this season', 'God save them https://t.co/x0YgLiBUCF', '@KingViil Na the best quote be this👏', '@InsaneDeraa 🤣🤣', '@dremva Na their tears sweet pass', 'RT @EplPidgin: I dey smell this Arsenal L like jo
# ...

# %%
# implementation of frequency distribution mapping

# freq = build_freq(tweets,label) #build frequencies distribution.
# x = np.zeros((m,3)) # initialize matrix m
# for i in range(m):  # for every tweet.
#     p_tweet = process_tweet(tweets[i])
#     X[i,:] = extract_features(p_tweets, freq) # extract features.
